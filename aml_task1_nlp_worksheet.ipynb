# %% [markdown]
# <a href="https://colab.research.google.com/github/wckdly/uos-ml-coursework/blob/main/aml_task1_nlp_worksheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# This Colab worksheet provides a starting point for Task 1 (the natural language processing task).

# %% [markdown]
# # Data Loading

# %%
# Download the data stored in a csv file
# If you're running all your experiments on a machine at home rather than using colab, then make sure you save it rather than repeatedly downloading it.

# training data
# !wget "https://sussex.box.com/shared/static/xjewvhv527xq083j8ehtsjcijs1i4kra.csv" -O sentiment_analysis_training_data.csv
# validation data
# !wget "https://sussex.box.com/shared/static/qv30jx3xfwer1va1k19nhndq2xaso67x.csv" -O sentiment_analysis_validation_data.csv
# test data (without labels)
# !wget "https://sussex.box.com/shared/static/zu44986583mlocifzyx6dsmqe20g1hlh.csv" -O sentiment_analysis_test_data.csv
# Out:
# --2026-05-24 14:13:38--  https://sussex.box.com/shared/static/xjewvhv527xq083j8ehtsjcijs1i4kra.csv
# Resolving sussex.box.com (sussex.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to sussex.box.com (sussex.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/xjewvhv527xq083j8ehtsjcijs1i4kra.csv [following]
# --2026-05-24 14:13:38--  https://sussex.box.com/public/static/xjewvhv527xq083j8ehtsjcijs1i4kra.csv
# Reusing existing connection to sussex.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://sussex.app.box.com/public/static/xjewvhv527xq083j8ehtsjcijs1i4kra.csv [following]
# --2026-05-24 14:13:38--  https://sussex.app.box.com/public/static/xjewvhv527xq083j8ehtsjcijs1i4kra.csv
# Resolving sussex.app.box.com (sussex.app.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to sussex.app.box.com (sussex.app.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://euc1.boxcloud.com/d/1/a1!-HaqmKU33FMb0aGz3CrfYRbrYEIFiAA7grxVoBrn5LoYfT0CAvh2SMiorhMI-cQbHCWA2vs-bmzxv3Ik1ROPI1VJ8JrF7HXuwmHWBqFddXvxyxODqyzzhlWDOHjq3dHKxamQ7oGrXAG1s3VNBQG-TDdlnDeNx_rz4X_W1Wm14IDbmDhojd5I0CbI0UrqX_GUmjruoHX-d1D0VN4xYbMlPdhdOLDAxRPM0UWSGbjncJjtnP39jcEJNBiMOLHiAO1r6jHPlzFJNnF7GHhOSr7xyCtR9UDbNXOtnZRilaO_j8OlsJ7EshTEJ3A0xW28qNlTbzwI0tniAHJm-24BaJ7AqJwyiqUQNabVKSbepiAcMkI6kmVSRjIsXJJMCiHwgs0PaG8pZa1yFaigpaB4AB6UQt6zpMGYsu_cLPDX9CkkSZZh-kVI-aHLk50hXXh-CMOiJH4LWLCP5aIlCVYQrfXrqyAI8Zm60E8-rxcaLQChcjC6xCaE-yK9taLNnUqSJjwFJIsEJP9jE6Q9GWMUmsCuUBHUzlBz7t7ajn5ZqPPNr05pdHtQBas5fm4_7Tkze80vFdN_8eeAiXXEkS0TqrwO4U_MRYSs_CLRtn6IY8Oea0wqrmufpSj-RyKILOunThoXxRyZivQ78iEWpOOGpolUvz8VrGNdqxtzHJ4HTNUDPhYClYAVBxwm-ZX407RUb8bz5Xr2uMa2gzkvsaZzmyWuqAsNwmFVd9g9fwtiKu8hWIXF10lHVSbnH3cDSJK6wKTqLL4W5ClFsyOOBsloGcsMLbJ57xdH0DBNwWQj1epBrky1wLqNsrFU7aMa7n_dHLzUIz0d0ftPzJpyF28BiZxKW9w-n-d-2JFyCcbq9a7reMyfOnm_Tuf53trZOwyL7mxWgWJVOyCg12rVtnBKWtiG0F12NyzmEQ41qFpOPvXRDMlCR1GjC5cog0DLo0RqTQhqd57WdrLTROeN9rCH1hcGKfdYD9E18N1ULXANf0TqUQ40PmIqMQY4GmrjSMjAZ1C1y3uYmh2gFachMhFss4Bg2UVPvDW2jt6H9vCFkd9E_7EBQsdojA3QX-AEuaGOnC_DQ1wBexeuXqGpO3vV5hrR2BHTRfG67y6I5b8sx3M7UbfIjIqpFIjbpb2d7SFPUQRw1c7sbBEUv4rN107Q5kDxz92FfZQlUdjBX2U5E6jWp5NfShiHVjNFPcfP5mtJ7HVe3R32bBMpXc-aVMhSQa8Y1s4EZklugAwVPM3ONWN5YiXK5M6dc-aJcRN_dLzsfMMMVnNIrylEOBN6VOHRNRqDJoUHK9FfP9LhqDmFpfMEb2QNDlhzkuQT80Q9QHoT0rmVhdIxUomgZyMR_7sCzP8NH_r1nyXGZqo-mP4OZiFgawObxN4UFUwd6Dmdlqzb55lZVwWXC2l74uwso9utX8LEfLf57beAESzpIixp7GJcVJydsMGKMrHCvxl-EAKBECpP32KTsi4QUZVWP0Jt9TiWwx5gAFV5WFmlJzlUMXyoYa1clPIIrxPY8AbOyikjRUV-qSEmZpcCWs5AHEWgMomwbg../download [following]
# --2026-05-24 14:13:39--  https://euc1.boxcloud.com/d/1/a1!-HaqmKU33FMb0aGz3CrfYRbrYEIFiAA7grxVoBrn5LoYfT0CAvh2SMiorhMI-cQbHCWA2vs-bmzxv3Ik1ROPI1VJ8JrF7HXuwmHWBqFddXvxyxODqyzzhlWDOHjq3dHKxamQ7oGrXAG1s3VNBQG-TDdlnDeNx_rz4X_W1Wm14IDbmDhojd5I0CbI0UrqX_GUmjruoHX-d1D0VN4xYbMlPdhdOLDAxRPM0UWSGbjncJjtnP39jcEJNBiMOLHiAO1r6jHPlzFJNnF7GHhOSr7xyCtR9UDbNXOtnZRilaO_j8OlsJ7EshTEJ3A0xW28qNlTbzwI0tniAHJm-24BaJ7AqJwyiqUQNabVKSbepiAcMkI6kmVSRjIsXJJMCiHwgs0PaG8pZa1yFaigpaB4AB6UQt6zpMGYsu_cLPDX9CkkSZZh-kVI-aHLk50hXXh-CMOiJH4LWLCP5aIlCVYQrfXrqyAI8Zm60E8-rxcaLQChcjC6xCaE-yK9taLNnUqSJjwFJIsEJP9jE6Q9GWMUmsCuUBHUzlBz7t7ajn5ZqPPNr05pdHtQBas5fm4_7Tkze80vFdN_8eeAiXXEkS0TqrwO4U_MRYSs_CLRtn6IY8Oea0wqrmufpSj-RyKILOunThoXxRyZivQ78iEWpOOGpolUvz8VrGNdqxtzHJ4HTNUDPhYClYAVBxwm-ZX407RUb8bz5Xr2uMa2gzkvsaZzmyWuqAsNwmFVd9g9fwtiKu8hWIXF10lHVSbnH3cDSJK6wKTqLL4W5ClFsyOOBsloGcsMLbJ57xdH0DBNwWQj1epBrky1wLqNsrFU7aMa7n_dHLzUIz0d0ftPzJpyF28BiZxKW9w-n-d-2JFyCcbq9a7reMyfOnm_Tuf53trZOwyL7mxWgWJVOyCg12rVtnBKWtiG0F12NyzmEQ41qFpOPvXRDMlCR1GjC5cog0DLo0RqTQhqd57WdrLTROeN9rCH1hcGKfdYD9E18N1ULXANf0TqUQ40PmIqMQY4GmrjSMjAZ1C1y3uYmh2gFachMhFss4Bg2UVPvDW2jt6H9vCFkd9E_7EBQsdojA3QX-AEuaGOnC_DQ1wBexeuXqGpO3vV5hrR2BHTRfG67y6I5b8sx3M7UbfIjIqpFIjbpb2d7SFPUQRw1c7sbBEUv4rN107Q5kDxz92FfZQlUdjBX2U5E6jWp5NfShiHVjNFPcfP5mtJ7HVe3R32bBMpXc-aVMhSQa8Y1s4EZklugAwVPM3ONWN5YiXK5M6dc-aJcRN_dLzsfMMMVnNIrylEOBN6VOHRNRqDJoUHK9FfP9LhqDmFpfMEb2QNDlhzkuQT80Q9QHoT0rmVhdIxUomgZyMR_7sCzP8NH_r1nyXGZqo-mP4OZiFgawObxN4UFUwd6Dmdlqzb55lZVwWXC2l74uwso9utX8LEfLf57beAESzpIixp7GJcVJydsMGKMrHCvxl-EAKBECpP32KTsi4QUZVWP0Jt9TiWwx5gAFV5WFmlJzlUMXyoYa1clPIIrxPY8AbOyikjRUV-qSEmZpcCWs5AHEWgMomwbg../download
# Resolving euc1.boxcloud.com (euc1.boxcloud.com)... 74.112.186.163, 2620:117:bff0:66::
# Connecting to euc1.boxcloud.com (euc1.boxcloud.com)|74.112.186.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3957814 (3.8M) [text/csv]
# Saving to: ‘sentiment_analysis_training_data.csv’
#
# sentiment_analysis_ 100%[===================>]   3.77M  4.44MB/s    in 0.9s
#
# 2026-05-24 14:13:40 (4.44 MB/s) - ‘sentiment_analysis_training_data.csv’ saved [3957814/3957814]
#
# --2026-05-24 14:13:40--  https://sussex.box.com/shared/static/qv30jx3xfwer1va1k19nhndq2xaso67x.csv
# Resolving sussex.box.com (sussex.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to sussex.box.com (sussex.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/qv30jx3xfwer1va1k19nhndq2xaso67x.csv [following]
# --2026-05-24 14:13:40--  https://sussex.box.com/public/static/qv30jx3xfwer1va1k19nhndq2xaso67x.csv
# Reusing existing connection to sussex.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://sussex.app.box.com/public/static/qv30jx3xfwer1va1k19nhndq2xaso67x.csv [following]
# --2026-05-24 14:13:40--  https://sussex.app.box.com/public/static/qv30jx3xfwer1va1k19nhndq2xaso67x.csv
# Resolving sussex.app.box.com (sussex.app.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to sussex.app.box.com (sussex.app.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://euc1.boxcloud.com/d/1/a1!z8czwm409ej4hh5EYcgwBgI-E4uYrYFehKeFW70i0Dsjs20ZxLDlYccQVbALf0xSngjYWNFhoJFjg6CPyl7LUeG0H_DZ2vdF4U6XF_4UJTdj8T7dRNxr29FZJHQ8Dlihra776eOcyjLstN_9ij8Mw-v-GtL52FGYhogyXRAjQB0TomhUHSrCpAPmWGDrcMPtkSYMqcFDTRmTX7-zG3m_XPknVM-MggB6o1JaOUoFxMKwMS90hOgWpsFgp5QadwuhBwg2qGMoemnyRIcTUU1BTzWdOU6iPXKg-oYFqV0LpDlilNmWYcxAzHKUtcXPva3MvAufoI3YlVDp9MpNkSje8Q0oQAKDLJrpqeNTi__F65017n6RUg4VseEJMjk4o17ki13Aer238VGJa_nFCWJvF89AZDQ3kwbQ1XCwB2QZS3yXhNt-zZfq31Pj6AQQrF-f9hVeqhBS2dR9OdrEvRWddxYngm68-ue29x1sidNOijkviHmuY4Jq_enAf8vYcnp2itoCwhHlSENOmWDXDhXaMUjkI-vbaXRGAfzCRpjs-KXnOHsYTKIVpRLAOC7dstIfCRFmrMvE_f5BDkEEz9LLjNxvMANf5XdVdG1QiOQ0gQEY0ysZ89CYWVlDRUUAH4476PwF3QezoKCMV-1N6JerU_km2oNQbZ7Jxcd9fRDD6F018keQXTDitfYJbQ1Trlct9zI-mW8s8WS2eBJeydjsnekBRmHdkqSk08I_OgIk6u4oxy6AhDeSezlxNWACB0kiKxmYXXKmjkyspiq1gcJFABIffAHK78wcNCHiPjMdYFyUraURKgebFB0YbnFivDdCXZqXRHuui0jrZHGHKtEmhRZmiSI9OE8teC5ld4x8xifEfrVTVVUab9lI_Lcotd--ZnleS23r8Qv6Wya0tf4q9r-3PNg9q8D1uN7hbvg5c0u_Y1oqXSPE7Ix9H6B5ue65lx3UdxjQZVLNAKIpPyi0azZyYAYZVF_mLvjllr1pvaIw9m-DrGQ-Hqs2tslLzI243D-QueWDDMvddIFy54zBDTrJzGYiIzRRsKL7ixukZEoFeVbiNyErtbOhewjI48wQcoSodmpVKE34c_9A0c6MXpjwXKKjfvbc0e-2dg0jBP8DBKAsOamagj0vzOF1dUKAN_vrkTvrS-yWkEYT4m_D5tFQ16sDEcDI26dLTUPDnCk8Lhcgzyx-DdaEQxppEonoWc2KzOHXeyAb3tYxcqmvx0ckaWApQc9TPiJrE6QnpKaioPay-XAexXiUsG31SERekNSbnHGS-bAoHlA-C1oyOXSQwHAHkRuUNByYFEAhAtzKpL2ZCXWoiw9G3clt93swlbVYJ59QqlG-g2rtPkMiG6CrCoBVBhXDPLbjhmuBVPdvezt8Ct_5U4DdSQ0v-4i8OgYduzlK1ZxseFsi21nxH3_0GNIvwnr_HVifHo63rfPb7SmQMbfdTiJCcu0M-lj_K30DGjXg4TrfeTF30ifJLrCZM5HIKfmnhBVoGeQkPPMMQMStm97bC1rx3eFE7K5xb4WNN4YKapfSYY8tqUg-yrw./download [following]
# --2026-05-24 14:13:41--  https://euc1.boxcloud.com/d/1/a1!z8czwm409ej4hh5EYcgwBgI-E4uYrYFehKeFW70i0Dsjs20ZxLDlYccQVbALf0xSngjYWNFhoJFjg6CPyl7LUeG0H_DZ2vdF4U6XF_4UJTdj8T7dRNxr29FZJHQ8Dlihra776eOcyjLstN_9ij8Mw-v-GtL52FGYhogyXRAjQB0TomhUHSrCpAPmWGDrcMPtkSYMqcFDTRmTX7-zG3m_XPknVM-MggB6o1JaOUoFxMKwMS90hOgWpsFgp5QadwuhBwg2qGMoemnyRIcTUU1BTzWdOU6iPXKg-oYFqV0LpDlilNmWYcxAzHKUtcXPva3MvAufoI3YlVDp9MpNkSje8Q0oQAKDLJrpqeNTi__F65017n6RUg4VseEJMjk4o17ki13Aer238VGJa_nFCWJvF89AZDQ3kwbQ1XCwB2QZS3yXhNt-zZfq31Pj6AQQrF-f9hVeqhBS2dR9OdrEvRWddxYngm68-ue29x1sidNOijkviHmuY4Jq_enAf8vYcnp2itoCwhHlSENOmWDXDhXaMUjkI-vbaXRGAfzCRpjs-KXnOHsYTKIVpRLAOC7dstIfCRFmrMvE_f5BDkEEz9LLjNxvMANf5XdVdG1QiOQ0gQEY0ysZ89CYWVlDRUUAH4476PwF3QezoKCMV-1N6JerU_km2oNQbZ7Jxcd9fRDD6F018keQXTDitfYJbQ1Trlct9zI-mW8s8WS2eBJeydjsnekBRmHdkqSk08I_OgIk6u4oxy6AhDeSezlxNWACB0kiKxmYXXKmjkyspiq1gcJFABIffAHK78wcNCHiPjMdYFyUraURKgebFB0YbnFivDdCXZqXRHuui0jrZHGHKtEmhRZmiSI9OE8teC5ld4x8xifEfrVTVVUab9lI_Lcotd--ZnleS23r8Qv6Wya0tf4q9r-3PNg9q8D1uN7hbvg5c0u_Y1oqXSPE7Ix9H6B5ue65lx3UdxjQZVLNAKIpPyi0azZyYAYZVF_mLvjllr1pvaIw9m-DrGQ-Hqs2tslLzI243D-QueWDDMvddIFy54zBDTrJzGYiIzRRsKL7ixukZEoFeVbiNyErtbOhewjI48wQcoSodmpVKE34c_9A0c6MXpjwXKKjfvbc0e-2dg0jBP8DBKAsOamagj0vzOF1dUKAN_vrkTvrS-yWkEYT4m_D5tFQ16sDEcDI26dLTUPDnCk8Lhcgzyx-DdaEQxppEonoWc2KzOHXeyAb3tYxcqmvx0ckaWApQc9TPiJrE6QnpKaioPay-XAexXiUsG31SERekNSbnHGS-bAoHlA-C1oyOXSQwHAHkRuUNByYFEAhAtzKpL2ZCXWoiw9G3clt93swlbVYJ59QqlG-g2rtPkMiG6CrCoBVBhXDPLbjhmuBVPdvezt8Ct_5U4DdSQ0v-4i8OgYduzlK1ZxseFsi21nxH3_0GNIvwnr_HVifHo63rfPb7SmQMbfdTiJCcu0M-lj_K30DGjXg4TrfeTF30ifJLrCZM5HIKfmnhBVoGeQkPPMMQMStm97bC1rx3eFE7K5xb4WNN4YKapfSYY8tqUg-yrw./download
# Resolving euc1.boxcloud.com (euc1.boxcloud.com)... 74.112.186.163, 2620:117:bff0:66::
# Connecting to euc1.boxcloud.com (euc1.boxcloud.com)|74.112.186.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 399259 (390K) [text/csv]
# Saving to: ‘sentiment_analysis_validation_data.csv’
#
# sentiment_analysis_ 100%[===================>] 389.90K   993KB/s    in 0.4s
#
# 2026-05-24 14:13:42 (993 KB/s) - ‘sentiment_analysis_validation_data.csv’ saved [399259/399259]
#
# --2026-05-24 14:13:42--  https://sussex.box.com/shared/static/zu44986583mlocifzyx6dsmqe20g1hlh.csv
# Resolving sussex.box.com (sussex.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to sussex.box.com (sussex.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/zu44986583mlocifzyx6dsmqe20g1hlh.csv [following]
# --2026-05-24 14:13:42--  https://sussex.box.com/public/static/zu44986583mlocifzyx6dsmqe20g1hlh.csv
# Reusing existing connection to sussex.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://sussex.app.box.com/public/static/zu44986583mlocifzyx6dsmqe20g1hlh.csv [following]
# --2026-05-24 14:13:42--  https://sussex.app.box.com/public/static/zu44986583mlocifzyx6dsmqe20g1hlh.csv
# Resolving sussex.app.box.com (sussex.app.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to sussex.app.box.com (sussex.app.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://euc1.boxcloud.com/d/1/a1!S0Ng5D9jh8X3CPg_gJCqDntptT4nIB5UuBSKYAdpf5Xrb1m6mIRC9IZONEI87EXRD9plgg3xh3A_PH_WRM4bg1sKQBkyMtxTIfeBoEUKiFBcm5gFYtOXq6PS8qCDUifQ4UhRTAY6lqPRilc8zCpzjnUqDpabfHk7ABWPcZm0SAF4UJIGd4NFeQwtYW6Ai2FZHhS0O35BtYa6h52EDXdcvFUpB4Otu-fCnh1U_pguiysVhh5MrB7P2CS0l4X7Qytk_K4l85U0Vgy8hUrkUGKqzSWrACxGenI06EeAVU-d0rvksfhDIOFSj62VhJZauqW5mpQ4H00mi11KIDbUbfG0MFi0Ou-RofasQKAZeagOJK3FTsmBdC6mDN4lVD3QoPYUNm1M-mu_u1JAb2d5vPL5ucy5zNk7qBu2JN2oRY9wdvzAW5eJ82rSlJhGxAjd3QgXyO9yALe0QyIh8Em_tE8PRioYYztmufCBHzfVvlDeH4K-cEYwrHc77gHMx_dGqzyjLxql95d2ee9wFrRoS7wLajzCET3lnZswAYBDk5Hh3jexy35QvJ1uamYK0lDaSaSp_x5FZNmXdbQR2jYiAwThmYIQV8fQon0Cjp0hGwfIqTRQImHLe5cPrdNaAJvumuvH5GBHkcbkildxeo0GnROQJXguW7t7co2tcEcqkRv5YjSkC29X22TM4KOMjRaEaAkYqCTLOArBDGO23BCwAwF-AK0KZPhc7daluBp-2njGAfS7B1ivphznAL2yZjSUibJ_eHcWCpsy7Do2ikFbJEtpWH3e-iPFzSdnhFIMLvZpR4QX6UEp7jXVn0Ys5ztrtQ3vPlLGnq4CWjJg1w_zxveKFMI4Ku1ct4jIj5khv2C5C-_7EZ0smczNtLDWrMGxaDDF1I7gN_4t5sQQbsCkou7b57UYIInrJ33ZpAl_WhclcV13HjwKPFsXXuTghb-B_DAFcGGNRO3OJANojXe3dxD1nT3-Ssnz7Z4v9N7RvzS278oUhPyWvTJ8D1-ts_PkG_W53bHFLalstrTm0jDtzlNR8oKsj_0LiZOICIEUnGGTg1Gq7rJk4zdbnjTIKjAN9GKWAbhwGuPRTwUXjUoGcXalbhmuNse8YarUfTICZGZitTQQUv8BLU3_YifJ09GYnb2Qonu9Gp6HclPlZubme0IfxD9E6c3RdVn29P4IosQzB7Sx8GogHraGRNSS16Ek0GKhTMomgj_lzMR1Mwa8IFZUv07NUYgPJ_0x7RR0i21YhnfPCd-Rz_kzE43EiLO3tLiaEzm5gXt5UmUg5eQEOVQwywtFsNGfI8CIm9MQzic6E-s5tA9xIlIu1nv5EaFTfJtAlUbrm3BeeG7JnVGhzdImP8f6k9aJSaaksdkc5Uz4j9g3PgdeYbgCNM45ebd_USkcViUuIQVDuRsOjl7qOkTRLkPUuRQ-I1Vx0Ma15KIv7wHAAQunqggh8149RMjKgtag8VouCFH-6IDHW5zhzw_nLOkVU8aKUg7CKwow0nvsBs-o0lpByVDQOj3AYt5bg_AWwyUbzizV-yW-iFc./download [following]
# --2026-05-24 14:13:42--  https://euc1.boxcloud.com/d/1/a1!S0Ng5D9jh8X3CPg_gJCqDntptT4nIB5UuBSKYAdpf5Xrb1m6mIRC9IZONEI87EXRD9plgg3xh3A_PH_WRM4bg1sKQBkyMtxTIfeBoEUKiFBcm5gFYtOXq6PS8qCDUifQ4UhRTAY6lqPRilc8zCpzjnUqDpabfHk7ABWPcZm0SAF4UJIGd4NFeQwtYW6Ai2FZHhS0O35BtYa6h52EDXdcvFUpB4Otu-fCnh1U_pguiysVhh5MrB7P2CS0l4X7Qytk_K4l85U0Vgy8hUrkUGKqzSWrACxGenI06EeAVU-d0rvksfhDIOFSj62VhJZauqW5mpQ4H00mi11KIDbUbfG0MFi0Ou-RofasQKAZeagOJK3FTsmBdC6mDN4lVD3QoPYUNm1M-mu_u1JAb2d5vPL5ucy5zNk7qBu2JN2oRY9wdvzAW5eJ82rSlJhGxAjd3QgXyO9yALe0QyIh8Em_tE8PRioYYztmufCBHzfVvlDeH4K-cEYwrHc77gHMx_dGqzyjLxql95d2ee9wFrRoS7wLajzCET3lnZswAYBDk5Hh3jexy35QvJ1uamYK0lDaSaSp_x5FZNmXdbQR2jYiAwThmYIQV8fQon0Cjp0hGwfIqTRQImHLe5cPrdNaAJvumuvH5GBHkcbkildxeo0GnROQJXguW7t7co2tcEcqkRv5YjSkC29X22TM4KOMjRaEaAkYqCTLOArBDGO23BCwAwF-AK0KZPhc7daluBp-2njGAfS7B1ivphznAL2yZjSUibJ_eHcWCpsy7Do2ikFbJEtpWH3e-iPFzSdnhFIMLvZpR4QX6UEp7jXVn0Ys5ztrtQ3vPlLGnq4CWjJg1w_zxveKFMI4Ku1ct4jIj5khv2C5C-_7EZ0smczNtLDWrMGxaDDF1I7gN_4t5sQQbsCkou7b57UYIInrJ33ZpAl_WhclcV13HjwKPFsXXuTghb-B_DAFcGGNRO3OJANojXe3dxD1nT3-Ssnz7Z4v9N7RvzS278oUhPyWvTJ8D1-ts_PkG_W53bHFLalstrTm0jDtzlNR8oKsj_0LiZOICIEUnGGTg1Gq7rJk4zdbnjTIKjAN9GKWAbhwGuPRTwUXjUoGcXalbhmuNse8YarUfTICZGZitTQQUv8BLU3_YifJ09GYnb2Qonu9Gp6HclPlZubme0IfxD9E6c3RdVn29P4IosQzB7Sx8GogHraGRNSS16Ek0GKhTMomgj_lzMR1Mwa8IFZUv07NUYgPJ_0x7RR0i21YhnfPCd-Rz_kzE43EiLO3tLiaEzm5gXt5UmUg5eQEOVQwywtFsNGfI8CIm9MQzic6E-s5tA9xIlIu1nv5EaFTfJtAlUbrm3BeeG7JnVGhzdImP8f6k9aJSaaksdkc5Uz4j9g3PgdeYbgCNM45ebd_USkcViUuIQVDuRsOjl7qOkTRLkPUuRQ-I1Vx0Ma15KIv7wHAAQunqggh8149RMjKgtag8VouCFH-6IDHW5zhzw_nLOkVU8aKUg7CKwow0nvsBs-o0lpByVDQOj3AYt5bg_AWwyUbzizV-yW-iFc./download
# Resolving euc1.boxcloud.com (euc1.boxcloud.com)... 74.112.186.163, 2620:117:bff0:66::
# Connecting to euc1.boxcloud.com (euc1.boxcloud.com)|74.112.186.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 511602 (500K) [text/csv]
# Saving to: ‘sentiment_analysis_test_data.csv’
#
# sentiment_analysis_ 100%[===================>] 499.61K  1.24MB/s    in 0.4s
#
# 2026-05-24 14:13:43 (1.24 MB/s) - ‘sentiment_analysis_test_data.csv’ saved [511602/511602]

# %% [markdown]
# # Load the data

# %%
import pandas as pd

# load the training data using np.load
# repeat this for validation and test data, but note the latter has no labels
data_train = pd.read_csv('sentiment_analysis_training_data.csv')

# extract the text
text_train = data_train['text'].values
# and the labels
labels_train = data_train['label'].values
print(data_train.shape, text_train.shape, labels_train.shape)

data_val = pd.read_csv('sentiment_analysis_validation_data.csv')
# extract the text
text_val = data_val['text'].values
# and the labels
labels_val = data_val['label'].values
print(data_val.shape, text_val.shape, labels_val.shape)

data_test = pd.read_csv('sentiment_analysis_test_data.csv')
# extract the text
text_test = data_test['text'].values
print(data_test.shape, text_test.shape)
# Out:
# (11503, 2) (11503,) (11503,)
# (1397, 2) (1397,) (1397,)
# (1434, 1) (1434,)

# %% [markdown]
# # Data Visualisation
# Here's an example of how to display the text based on its label.

# %%
def print_text(text, label):
  if label == 0:
    print (text, '\nlabel == 0')
  else:
    print (text, '\nlabel == 1')

import numpy as np
idx = np.random.randint(0, text_train.shape[0])
print_text(text_train[idx], labels_train[idx])
# Out:
# a prolonged extrusion of psychopathic pulp .
# label == 0

# %% [markdown]
# # Calculating Confusion Matrix and exporting results

# %%
from sklearn.metrics import confusion_matrix

def get_confusion_matrix(true_label, pred_label):
  """
  Calculate the confusion matrix for your predicted labels. See https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html
  :param pred_label: Array of predicted labels
  :param true_label: Array of corresponding ground truth (test) labels
  :return: Confusion matrix whose i-th row and j-th column entry indicates the number of samples with true label being i-th class and predicted label being j-th class.
  """
  return confusion_matrix(true_label, pred_label)

# %%
def save_as_csv(pred_labels, location = '.'):
    """
    Save the labels out as a .csv file
    :pred_labels: numpy array of shape (no_test_labels,) to be saved
    :param location: Directory to save results.csv in. Default to current working directory
    """
    assert pred_labels.shape[0]==1434, 'wrong number of labels, should be 1434 test labels'
    np.savetxt(location + '/results_task1.csv', pred_labels, delimiter=',')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# convert text into numerical features
vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)

# learn vocabulary from training data
X_train = vectorizer.fit_transform(text_train)

# transform validation data using same vocabulary
X_val = vectorizer.transform(text_val)

# create model
model = LogisticRegression(max_iter=1000)

# train model
model.fit(X_train, labels_train)

# make predictions
pred_val = model.predict(X_val)

# evaluate
accuracy = accuracy_score(labels_val, pred_val)

print("Validation Accuracy:", accuracy)

print("\nClassification Report:\n")
print(classification_report(labels_val, pred_val))
